# %% [markdown]
# # SOLUTIONS: Writing a function to sort an array
#
# Sorting arrays is a common operation. Making a sorting algorithm that is *fast* is very important and there are many different approaches to the problem (python, for example uses "Timsort"):
#
# https://en.wikipedia.org/wiki/Sorting_algorithm
#
# There is a rule though: If you have an array that contains random input, then you will require an average of `O(N log(N))` operations to sort the array. If the array is *not* random though, this can be shorter (e.g. if the array is already sorted, this can be done in `O(N)`, which is the cost required to identify that the array *is* sorted.
#
# As this is the last exercise, let's make this challenging:
#
# * Write your own code that will take as input an array of numbers. Return a sorted *copy* of the array (the original array should be unchanged). Don't worry too much about making the code fast until you have something that works. When you have something that works, see how you can use the tools presented above to make it as fast as possible.

# %%
import copy
def sort_array(unsorted_array):
    # This line will copy the array so that the input will be preserved.
    # After this you can do what you want to unsorted_array
    unsorted_array = copy.deepcopy(unsorted_array)

    sorted_array=unsorted_array

    for j in range(0,len(sorted_array)-1):
      swapped_this_round = False
      for i in range(0,len(sorted_array)-1):
        a = sorted_array[i]
        b = sorted_array[i+1]
        if a > b:
          sorted_array[i] = b
          sorted_array[i+1] = a
          swapped_this_round = True
      # Break the loop if I didn't need to swap any elements
      if not swapped_this_round:
        break
    return sorted_array

# %%
# Use this cell to profile your code.
import sys
# !{sys.executable} -m pip install line_profiler
# !{sys.executable} -m pip install memory_profiler

# %load_ext line_profiler
# %load_ext memory_profiler
# Out:
# Requirement already satisfied: line_profiler in /usr/local/lib/python3.12/dist-packages (5.0.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from line_profiler) (4.15.0)
# Requirement already satisfied: memory_profiler in /usr/local/lib/python3.12/dist-packages (0.61.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from memory_profiler) (5.9.5)
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler

# %%
# Example input array
example_array = [3,8,9,4,1,5]

# %%
# Timing and profiling
# %timeit sort_array(example_array)

# %lprun -T lprof0 -f sort_array sort_array(example_array)
print(open('lprof0', 'r').read())
# Out:
# 437 ms ± 153 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# *** Profile printout saved to text file 'lprof0'.
# Timer unit: 1e-09 s
#
# Total time: 2.36174 s
# File: /tmp/ipykernel_2135/3007922481.py
# Function: sort_array at line 2
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      2                                           def sort_array(unsorted_array):
#      3                                               # This line will copy the array so that the input will be preserved.
#      4                                               # After this you can do what you want to unsorted_array
#      5         1      94778.0  94778.0      0.0      unsorted_array = copy.deepcopy(unsorted_array)
#      6
#      7         1        739.0    739.0      0.0      sorted_array=unsorted_array
#      8       989     511890.0    517.6      0.0      for j in range(0,len(sorted_array)-1):
#      9       989     407036.0    411.6      0.0        swapped_this_round = False
#     10    989000  414566889.0    419.2     17.6        for i in range(0,len(sorted_array)-1):
#     11    988011  522579686.0    528.9     22.1          a = sorted_array[i]
#     12    988011  536892472.0    543.4     22.7          b = sorted_array[i+1]
#     13    988011  423298025.0    428.4     17.9          if a > b:
#     14    241712  168686999.0    697.9      7.1            sorted_array[i] = b
#     15    241712  168905706.0    698.8      7.2            sorted_array[i+1] = a
#     16    241712  125224573.0    518.1      5.3            swapped_this_round = True
#     17                                                 # Break the loop if I didn't need to swap any elements
#     18       989     568327.0    574.6      0.0        if not swapped_this_round:
#     19         1        641.0    641.0      0.0          break
#     20         1       3486.0   3486.0      0.0      return sorted_array

# %%
# An example if how to run quicker....not sure this will work for large arrays

import copy
def sort_array_1(unsorted_array):
    # This line will copy the array so that the input will be preserved.
    # After this you can do what you want to unsorted_array
    unsorted_array = copy.deepcopy(unsorted_array)

    sorted_array=unsorted_array

    for j in range(0,len(sorted_array)-1):
      for i in range(0,len(sorted_array)-1):
        a = sorted_array[i]
        b = sorted_array[i+1]
        if a > b:
          sorted_array[i] = b
          sorted_array[i+1] = a
    return sorted_array

# %%
# Timing and profiling - I need to do something to define a and b better or
# can i decrease the number of times I need to do this operation?
# %timeit sort_array_1(example_array)

# %lprun -T lprof0 -f sort_array_1 sort_array_1(example_array)
print(open('lprof0', 'r').read())
# Out:
# 319 ms ± 6.37 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# *** Profile printout saved to text file 'lprof0'.
# Timer unit: 1e-09 s
#
# Total time: 2.50089 s
# File: /tmp/ipykernel_2135/1581633729.py
# Function: sort_array_1 at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                           def sort_array_1(unsorted_array):
#      5                                               # This line will copy the array so that the input will be preserved.
#      6                                               # After this you can do what you want to unsorted_array
#      7         1      63197.0  63197.0      0.0      unsorted_array = copy.deepcopy(unsorted_array)
#      8
#      9         1        761.0    761.0      0.0      sorted_array=unsorted_array
#     10
#     11      1000     513014.0    513.0      0.0      for j in range(0,len(sorted_array)-1):
#     12    999000  503959214.0    504.5     20.2        for i in range(0,len(sorted_array)-1):
#     13    998001  614490890.0    615.7     24.6          a = sorted_array[i]
#     14    998001  656119374.0    657.4     26.2          b = sorted_array[i+1]
#     15    998001  480611007.0    481.6     19.2          if a > b:
#     16    241712  122058313.0    505.0      4.9            sorted_array[i] = b
#     17    241712  123066137.0    509.1      4.9            sorted_array[i+1] = a
#     18         1       6057.0   6057.0      0.0      return sorted_array
